# %%
import pandas as pd
import numpy as np

# %%
# cwd = os.path.dirname(os.path.realpath(__file__))
FOI_DEV_LIST = [] # '', 'Add', 'Change'
for i in range(1998, 2008):
    FOI_DEV_LIST.append(str(i))

baseline_col = ['BASELINE_BRAND_NAME', 'BASELINE_GENERIC_NAME', 'BASELINE_MODEL_NO', 'BASELINE_CATALOG_NO',
				'BASELINE_OTHER_ID_NO', 'BASELINE_DEVICE_FAMILY', 'BASELINE_SHELF_LIFE_CONTAINED',
				'BASELINE_SHELF_LIFE_IN_MONTHS', 'BASELINE_PMA_FLAG', 'BASELINE_PMA_NO', 'BASELINE_510_K__FLAG',
				'BASELINE_510_K__NO', 'BASELINE_PREAMENDMENT', 'BASELINE_TRANSITIONAL', 'BASELINE_510_K__EXEMPT_FLAG',
				'BASELINE_DATE_FIRST_MARKETED', 'BASELINE_DATE_CEASED_MARKETING']    

df_BI = pd.read_csv('1_BI_KEY_list.txt', header=None, names=['MDR_REPORT_KEY'])

# %%
df_list = []
for s in FOI_DEV_LIST:
    df = pd.read_csv('foidev/foidev'+s+'.txt', sep='|', header=0,
                                  encoding='ISO-8859-1', error_bad_lines=False)
    df_list.append(df)
df_BASELINE = pd.concat(df_list, axis=0)
del df_list

df_BI_BASELINE = df_BASELINE.merge(df_BI, on=['MDR_REPORT_KEY'], how='inner')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# b'Skipping line 16452: expected 45 fields, saw 46\n'
# b'Skipping line 48741: expected 45 fields, saw 57\n'
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# b'Skipping line 23599: expected 45 fields, saw 48\n'
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (14,31,35,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
line_num = df_BI_BASELINE.shape[0]
for b in baseline_col:
    print(b, 'missing :', len(df_BI_BASELINE[b].isnull()), 'out of', line_num)
# Out:
# BASELINE_BRAND_NAME missing : 14735 out of 14735
# BASELINE_GENERIC_NAME missing : 14735 out of 14735
# BASELINE_MODEL_NO missing : 14735 out of 14735
# BASELINE_CATALOG_NO missing : 14735 out of 14735
# BASELINE_OTHER_ID_NO missing : 14735 out of 14735
# BASELINE_DEVICE_FAMILY missing : 14735 out of 14735
# BASELINE_SHELF_LIFE_CONTAINED missing : 14735 out of 14735
# BASELINE_SHELF_LIFE_IN_MONTHS missing : 14735 out of 14735
# BASELINE_PMA_FLAG missing : 14735 out of 14735
# BASELINE_PMA_NO missing : 14735 out of 14735
# BASELINE_510_K__FLAG missing : 14735 out of 14735
# BASELINE_510_K__NO missing : 14735 out of 14735
# BASELINE_PREAMENDMENT missing : 14735 out of 14735
# BASELINE_TRANSITIONAL missing : 14735 out of 14735
# BASELINE_510_K__EXEMPT_FLAG missing : 14735 out of 14735
# BASELINE_DATE_FIRST_MARKETED missing : 14735 out of 14735
# BASELINE_DATE_CEASED_MARKETING missing : 14735 out of 14735

# %%
df_BI_BASELINE.head()
# Out:
#    MDR_REPORT_KEY  DEVICE_EVENT_KEY IMPLANT_FLAG DATE_REMOVED_FLAG  \
# 0          203929          198075.0            Y                 V
# 1          203787          197937.0            Y                 V
# 2          203782          197932.0            Y                 V
# 3          203774          197924.0            Y                 V
# 4          203753          197903.0            Y                 V
#
#    DEVICE_SEQUENCE_NO DATE_RECEIVED  \
# 0                   1    12/23/1998
# 1                   1    12/21/1998
# 2                   1    12/21/1998
# 3                   1    12/21/1998
# 4                   1    12/21/1998
#
#                                           BRAND_NAME        GENERIC_NAME  \
# 0                                        DOW CORNING      BREAST IMPLANT
# 1                   SILTEX SALINE MAMMARY PROSTHESIS  MAMMARY PROSTHESIS
# 2                   SMOOTH SALINE MAMMARY PROSTHESIS  MAMMARY PROSTHESIS
# 3  SPECTRUM CONTOUR POST-OPERATIVELY ADJUSTABLE M...  MAMMARY PROSTHESIS
# 4                   SMOOTH SALINE MAMMARY PROSTHESIS  MAMMARY PROSTHESIS
#
#   MANUFACTURER_D_NAME  MANUFACTURER_D_ADDRESS_1  \
# 0   DOW CORNING CORP.                PO BOX 995
# 1              MENTOR  3041 SKYWAY CIRCLE NORTH
# 2              MENTOR  3041 SKYWAY CIRCLE NORTH
# 3              MENTOR  3041 SKYWAY CIRCLE NORTH
# 4              MENTOR  3041 SKYWAY CIRCLE NORTH
#
#                ...               BASELINE_SHELF_LIFE_IN_MONTHS  \
# 0              ...                                         NaN
# 1              ...                                          60
# 2              ...                                          60
# 3              ...                                          60
# 4              ...                                          60
#
#   BASELINE_PMA_FLAG BASELINE_PMA_NO BASELINE_510_K__FLAG BASELINE_510_K__NO  \
# 0               NaN             NaN                  NaN                NaN
# 1                 Y         P940039                    N                NaN
# 2                 Y         P940039                    N                NaN
# 3                 Y         P950004                    Y            K883751
# 4                 Y         P940039                    N                NaN
#
#   BASELINE_PREAMENDMENT BASELINE_TRANSITIONAL BASELINE_510_K__EXEMPT_FLAG  \
# 0                   NaN                   NaN                         NaN
# 1                     N                     N                           N
# 2                     N                     N                           N
# 3                     N                     N                           N
# 4                     N                     N                           N
#
#   BASELINE_DATE_FIRST_MARKETED BASELINE_DATE_CEASED_MARKETING
# 0                          NaN                            NaN
# 1                   04/01/1984                     08/08/1995
# 2                   04/01/1984                     08/08/1995
# 3                   12/01/1992                            NaN
# 4                   04/01/1984                     08/08/1995
#
# [5 rows x 45 columns]
